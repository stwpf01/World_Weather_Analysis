# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Weather": city_descr})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pimenta bueno
# Processing Record 2 of Set 1 | samarai
# Processing Record 3 of Set 1 | anadyr
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | chalette-sur-loing
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | ishigaki
# Processing Record 8 of Set 1 | codrington
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | cidreira
# Processing Record 11 of Set 1 | guiyang
# Processing Record 12 of Set 1 | pangkalanbuun
# Processing Record 13 of Set 1 | port blair
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | shache
# Processing Record 16 of Set 1 | grand baie
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 1 | nome
# Processing Record 21 of Set 1 | manavalakurichi
# Processing Record 22 of Set 1 | kununurra
# Processing Record 23 of Set 1 | tafresh
# Processing Record 24 of Set 1 | ambon
# Processing Record 25 of Set 1 | aykhal
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 1 | oga
# Processing Record 33 of Set 1 | tarakan
# Processing Record 34 of Set 1 | kultuk
# Processing Record 35 of Set 1 | severo-kurilsk
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | ostrovnoy
# Processing Record 38 of Set 1 | parga
# Processing Record 39 of Set 1 | denpasar
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | griffith
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | winslow
# Processing Record 44 of Set 1 | san luis
# Processing Record 45 of Set 1 | salalah
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | beboto
# Processing Record 48 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | henties bay
# Processing Record 1 of Set 2 | cayenne
# Processing Record 2 of Set 2 | kulhudhuffushi
# Processing Record 3 of Set 2 | pangai
# Processing Record 4 of Set 2 | shchuchye
# City not found. Skipping...
# Processing Record 5 of Set 2 | tigil
# Processing Record 6 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 2 | ilulissat
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | rikitea
# Processing Record 11 of Set 2 | hasaki
# Processing Record 12 of Set 2 | tasiilaq
# Processing Record 13 of Set 2 | aksarka
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | amaigbo
# Processing Record 16 of Set 2 | sistranda
# Processing Record 17 of Set 2 | illapel
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | fatehpur
# Processing Record 20 of Set 2 | turukhansk
# Processing Record 21 of Set 2 | the valley
# Processing Record 22 of Set 2 | joao camara
# Processing Record 23 of Set 2 | salamanca
# Processing Record 24 of Set 2 | ibotirama
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | nuuk
# Processing Record 28 of Set 2 | port hardy
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | concordia
# Processing Record 32 of Set 2 | hamilton
# Processing Record 33 of Set 2 | gubkinskiy
# Processing Record 34 of Set 2 | port lincoln
# Processing Record 35 of Set 2 | longyearbyen
# Processing Record 36 of Set 2 | flinders
# Processing Record 37 of Set 2 | cherskiy
# Processing Record 38 of Set 2 | mali
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | morwell
# Processing Record 41 of Set 2 | northam
# Processing Record 42 of Set 2 | sabang
# Processing Record 43 of Set 2 | broome
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | rayagada
# Processing Record 48 of Set 2 | mitu
# Processing Record 49 of Set 2 | niksic
# Processing Record 50 of Set 2 | hualmay
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | guerrero negro
# Processing Record 3 of Set 3 | jasper
# Processing Record 4 of Set 3 | kirakira
# Processing Record 5 of Set 3 | esperance
# Processing Record 6 of Set 3 | saint-augustin
# Processing Record 7 of Set 3 | saint-francois
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | bengkulu
# Processing Record 10 of Set 3 | artyom
# Processing Record 11 of Set 3 | geraldton
# Processing Record 12 of Set 3 | mao
# Processing Record 13 of Set 3 | nanortalik
# Processing Record 14 of Set 3 | hof
# Processing Record 15 of Set 3 | faanui
# Processing Record 16 of Set 3 | yar-sale
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | provideniya
# Processing Record 19 of Set 3 | minab
# Processing Record 20 of Set 3 | talnakh
# Processing Record 21 of Set 3 | guapi
# Processing Record 22 of Set 3 | sinnamary
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | koulikoro
# Processing Record 25 of Set 3 | finschhafen
# Processing Record 26 of Set 3 | port elizabeth
# Processing Record 27 of Set 3 | inhambane
# Processing Record 28 of Set 3 | kamaishi
# Processing Record 29 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | zeya
# Processing Record 32 of Set 3 | ciudad bolivar
# Processing Record 33 of Set 3 | punta arenas
# Processing Record 34 of Set 3 | qaanaaq
# Processing Record 35 of Set 3 | guangyuan
# Processing Record 36 of Set 3 | mount isa
# Processing Record 37 of Set 3 | college
# Processing Record 38 of Set 3 | aswan
# Processing Record 39 of Set 3 | iqaluit
# Processing Record 40 of Set 3 | sola
# Processing Record 41 of Set 3 | upernavik
# Processing Record 42 of Set 3 | taoudenni
# Processing Record 43 of Set 3 | mar del plata
# Processing Record 44 of Set 3 | pilao arcado
# City not found. Skipping...
# Processing Record 45 of Set 3 | airai
# Processing Record 46 of Set 3 | aklavik
# Processing Record 47 of Set 3 | komsomolskiy
# Processing Record 48 of Set 3 | tagusao
# Processing Record 49 of Set 3 | bhainsa
# Processing Record 50 of Set 3 | dali
# Processing Record 1 of Set 4 | butaritari
# Processing Record 2 of Set 4 | antsla
# Processing Record 3 of Set 4 | goderich
# Processing Record 4 of Set 4 | zaysan
# Processing Record 5 of Set 4 | sisimiut
# Processing Record 6 of Set 4 | mount gambier
# Processing Record 7 of Set 4 | iguape
# Processing Record 8 of Set 4 | bonavista
# Processing Record 9 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 4 | ixtapa
# Processing Record 11 of Set 4 | lavrentiya
# Processing Record 12 of Set 4 | mindelo
# Processing Record 13 of Set 4 | tuatapere
# Processing Record 14 of Set 4 | hofn
# Processing Record 15 of Set 4 | coihaique
# Processing Record 16 of Set 4 | waingapu
# Processing Record 17 of Set 4 | torbay
# Processing Record 18 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 4 | pedasi
# Processing Record 20 of Set 4 | bathsheba
# Processing Record 21 of Set 4 | egvekinot
# Processing Record 22 of Set 4 | mahebourg
# Processing Record 23 of Set 4 | acarau
# Processing Record 24 of Set 4 | nalut
# Processing Record 25 of Set 4 | nayoro
# Processing Record 26 of Set 4 | tam ky
# Processing Record 27 of Set 4 | chihuahua
# Processing Record 28 of Set 4 | kampar
# Processing Record 29 of Set 4 | pevek
# Processing Record 30 of Set 4 | marsh harbour
# Processing Record 31 of Set 4 | srednekolymsk
# Processing Record 32 of Set 4 | vidim
# Processing Record 33 of Set 4 | sitka
# Processing Record 34 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | kidal
# Processing Record 37 of Set 4 | shingu
# Processing Record 38 of Set 4 | santa
# Processing Record 39 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 4 | palmer
# Processing Record 41 of Set 4 | saint-philippe
# Processing Record 42 of Set 4 | chicama
# Processing Record 43 of Set 4 | norman wells
# Processing Record 44 of Set 4 | arenapolis
# Processing Record 45 of Set 4 | sobolevo
# Processing Record 46 of Set 4 | fuente palmera
# Processing Record 47 of Set 4 | todos santos
# Processing Record 48 of Set 4 | kieta
# Processing Record 49 of Set 4 | malanje
# Processing Record 50 of Set 4 | lompoc
# Processing Record 1 of Set 5 | minas
# Processing Record 2 of Set 5 | katsuura
# Processing Record 3 of Set 5 | asau
# Processing Record 4 of Set 5 | chokurdakh
# Processing Record 5 of Set 5 | riyadh
# Processing Record 6 of Set 5 | lamu
# Processing Record 7 of Set 5 | east london
# Processing Record 8 of Set 5 | havelock
# Processing Record 9 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 5 | mitsamiouli
# Processing Record 11 of Set 5 | sao joao da barra
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | gornozavodsk
# Processing Record 14 of Set 5 | kavaratti
# Processing Record 15 of Set 5 | tulungagung
# Processing Record 16 of Set 5 | podbelsk
# City not found. Skipping...
# Processing Record 17 of Set 5 | hailin
# Processing Record 18 of Set 5 | bethel
# Processing Record 19 of Set 5 | shubarshi
# Processing Record 20 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 5 | mangai
# Processing Record 22 of Set 5 | kiama
# Processing Record 23 of Set 5 | san vicente
# Processing Record 24 of Set 5 | coquimbo
# Processing Record 25 of Set 5 | eirunepe
# Processing Record 26 of Set 5 | russell
# Processing Record 27 of Set 5 | camacha
# Processing Record 28 of Set 5 | mildura
# Processing Record 29 of Set 5 | bambous virieux
# Processing Record 30 of Set 5 | san quintin
# Processing Record 31 of Set 5 | colotlan
# Processing Record 32 of Set 5 | nikolskoye
# Processing Record 33 of Set 5 | baykit
# Processing Record 34 of Set 5 | chipinge
# Processing Record 35 of Set 5 | zhigansk
# Processing Record 36 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 5 | launceston
# Processing Record 38 of Set 5 | kahului
# Processing Record 39 of Set 5 | sahuaripa
# Processing Record 40 of Set 5 | okha
# Processing Record 41 of Set 5 | marilandia
# Processing Record 42 of Set 5 | san patricio
# Processing Record 43 of Set 5 | laguna
# Processing Record 44 of Set 5 | isangel
# Processing Record 45 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 46 of Set 5 | kuytun
# Processing Record 47 of Set 5 | kangasala
# Processing Record 48 of Set 5 | sao filipe
# Processing Record 49 of Set 5 | subaytilah
# City not found. Skipping...
# Processing Record 50 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 6 | hermanus
# Processing Record 2 of Set 6 | tazovskiy
# Processing Record 3 of Set 6 | maceio
# Processing Record 4 of Set 6 | kushmurun
# Processing Record 5 of Set 6 | tongliao
# Processing Record 6 of Set 6 | vila
# Processing Record 7 of Set 6 | manjacaze
# Processing Record 8 of Set 6 | muyezerskiy
# Processing Record 9 of Set 6 | dubbo
# Processing Record 10 of Set 6 | hervey bay
# Processing Record 11 of Set 6 | khasan
# Processing Record 12 of Set 6 | thompson
# Processing Record 13 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 6 | koslan
# Processing Record 15 of Set 6 | khatanga
# Processing Record 16 of Set 6 | panjakent
# Processing Record 17 of Set 6 | tateyama
# Processing Record 18 of Set 6 | dunedin
# Processing Record 19 of Set 6 | chimbote
# Processing Record 20 of Set 6 | westport
# Processing Record 21 of Set 6 | saint george
# Processing Record 22 of Set 6 | babat
# Processing Record 23 of Set 6 | lucapa
# Processing Record 24 of Set 6 | phrai bung
# City not found. Skipping...
# Processing Record 25 of Set 6 | vrangel
# Processing Record 26 of Set 6 | bustamante
# Processing Record 27 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 28 of Set 6 | indian head
# Processing Record 29 of Set 6 | tautira
# Processing Record 30 of Set 6 | faya
# Processing Record 31 of Set 6 | havoysund
# Processing Record 32 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 6 | erzin
# Processing Record 34 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 6 | vung tau
# Processing Record 36 of Set 6 | qui nhon
# Processing Record 37 of Set 6 | meulaboh
# Processing Record 38 of Set 6 | price
# Processing Record 39 of Set 6 | bandarbeyla
# Processing Record 40 of Set 6 | dire
# Processing Record 41 of Set 6 | ibimirim
# Processing Record 42 of Set 6 | buala
# Processing Record 43 of Set 6 | salima
# Processing Record 44 of Set 6 | makakilo city
# Processing Record 45 of Set 6 | marzuq
# Processing Record 46 of Set 6 | mumford
# Processing Record 47 of Set 6 | ust-ilimsk
# Processing Record 48 of Set 6 | sonoita
# Processing Record 49 of Set 6 | kloulklubed
# Processing Record 50 of Set 6 | shahr-e babak
# Processing Record 1 of Set 7 | nova vicosa
# Processing Record 2 of Set 7 | horsham
# Processing Record 3 of Set 7 | bowen
# Processing Record 4 of Set 7 | kikwit
# Processing Record 5 of Set 7 | port macquarie
# Processing Record 6 of Set 7 | ponta delgada
# Processing Record 7 of Set 7 | buenaventura
# Processing Record 8 of Set 7 | hulan
# Processing Record 9 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 7 | whitehorse
# Processing Record 11 of Set 7 | namatanai
# Processing Record 12 of Set 7 | carnarvon
# Processing Record 13 of Set 7 | fairbanks
# Processing Record 14 of Set 7 | nabire
# Processing Record 15 of Set 7 | opelousas
# Processing Record 16 of Set 7 | thunder bay
# Processing Record 17 of Set 7 | solnechnyy
# Processing Record 18 of Set 7 | neryungri
# Processing Record 19 of Set 7 | portland
# Processing Record 20 of Set 7 | fayaoue
# Processing Record 21 of Set 7 | along
# Processing Record 22 of Set 7 | kabare
# Processing Record 23 of Set 7 | bud
# Processing Record 24 of Set 7 | udachnyy
# Processing Record 25 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 7 | kaitangata
# Processing Record 27 of Set 7 | nishihara
# Processing Record 28 of Set 7 | clyde river
# Processing Record 29 of Set 7 | pangnirtung
# Processing Record 30 of Set 7 | tiksi
# Processing Record 31 of Set 7 | poum
# Processing Record 32 of Set 7 | bonaventure
# Processing Record 33 of Set 7 | karratha
# Processing Record 34 of Set 7 | atambua
# Processing Record 35 of Set 7 | qaqortoq
# Processing Record 36 of Set 7 | zirandaro
# Processing Record 37 of Set 7 | sao jose da coroa grande
# Processing Record 38 of Set 7 | angoram
# Processing Record 39 of Set 7 | guozhen
# Processing Record 40 of Set 7 | chodavaram
# Processing Record 41 of Set 7 | nouadhibou
# Processing Record 42 of Set 7 | vila velha
# Processing Record 43 of Set 7 | huejuquilla el alto
# Processing Record 44 of Set 7 | acapulco
# Processing Record 45 of Set 7 | olbernhau
# Processing Record 46 of Set 7 | lebu
# Processing Record 47 of Set 7 | salcininkai
# Processing Record 48 of Set 7 | champerico
# Processing Record 49 of Set 7 | dashitou
# Processing Record 50 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 8 | cockburn town
# Processing Record 2 of Set 8 | iquitos
# Processing Record 3 of Set 8 | lakatoro
# Processing Record 4 of Set 8 | viedma
# Processing Record 5 of Set 8 | livingston
# Processing Record 6 of Set 8 | taltal
# Processing Record 7 of Set 8 | velizh
# Processing Record 8 of Set 8 | saint-georges
# Processing Record 9 of Set 8 | paramonga
# Processing Record 10 of Set 8 | saskylakh
# Processing Record 11 of Set 8 | luchegorsk
# Processing Record 12 of Set 8 | touros
# Processing Record 13 of Set 8 | whitianga
# Processing Record 14 of Set 8 | ayan
# Processing Record 15 of Set 8 | marechal candido rondon
# Processing Record 16 of Set 8 | pisco
# Processing Record 17 of Set 8 | rantepao
# Processing Record 18 of Set 8 | yerbogachen
# Processing Record 19 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 8 | goya
# Processing Record 21 of Set 8 | lazaro cardenas
# Processing Record 22 of Set 8 | poltavka
# Processing Record 23 of Set 8 | rocha
# Processing Record 24 of Set 8 | beyneu
# Processing Record 25 of Set 8 | coron
# Processing Record 26 of Set 8 | tutoia
# Processing Record 27 of Set 8 | port augusta
# Processing Record 28 of Set 8 | krasnyy chikoy
# Processing Record 29 of Set 8 | sheregesh
# Processing Record 30 of Set 8 | ahuimanu
# Processing Record 31 of Set 8 | takaka
# Processing Record 32 of Set 8 | xining
# Processing Record 33 of Set 8 | bilibino
# Processing Record 34 of Set 8 | mayumba
# Processing Record 35 of Set 8 | souillac
# Processing Record 36 of Set 8 | gat
# Processing Record 37 of Set 8 | leh
# Processing Record 38 of Set 8 | boende
# Processing Record 39 of Set 8 | nemuro
# Processing Record 40 of Set 8 | kokopo
# Processing Record 41 of Set 8 | varzea grande
# Processing Record 42 of Set 8 | sampit
# Processing Record 43 of Set 8 | san jeronimo
# Processing Record 44 of Set 8 | toftir
# City not found. Skipping...
# Processing Record 45 of Set 8 | abu dhabi
# Processing Record 46 of Set 8 | ramapuram
# Processing Record 47 of Set 8 | hadejia
# Processing Record 48 of Set 8 | staryy nadym
# Processing Record 49 of Set 8 | mareeba
# Processing Record 50 of Set 8 | amazar
# Processing Record 1 of Set 9 | jalu
# Processing Record 2 of Set 9 | kindu
# Processing Record 3 of Set 9 | adrar
# Processing Record 4 of Set 9 | krasnoarmeysk
# Processing Record 5 of Set 9 | high level
# Processing Record 6 of Set 9 | klaksvik
# Processing Record 7 of Set 9 | noshiro
# Processing Record 8 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 9 | boden
# Processing Record 11 of Set 9 | las cruces
# Processing Record 12 of Set 9 | byron bay
# Processing Record 13 of Set 9 | quang ngai
# Processing Record 14 of Set 9 | asfi
# Processing Record 15 of Set 9 | lorengau
# Processing Record 16 of Set 9 | calbuco
# Processing Record 17 of Set 9 | lata
# Processing Record 18 of Set 9 | kenai
# Processing Record 19 of Set 9 | nacozari
# Processing Record 20 of Set 9 | atherton
# Processing Record 21 of Set 9 | kuzovatovo
# Processing Record 22 of Set 9 | sovetskiy
# Processing Record 23 of Set 9 | vila franca do campo
# Processing Record 24 of Set 9 | gari
# Processing Record 25 of Set 9 | lebanon
# Processing Record 26 of Set 9 | benjamin constant
# Processing Record 27 of Set 9 | oranjemund
# Processing Record 28 of Set 9 | namibe
# Processing Record 29 of Set 9 | nelson bay
# Processing Record 30 of Set 9 | swindon
# Processing Record 31 of Set 9 | rauma
# Processing Record 32 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 9 | wanning
# Processing Record 34 of Set 9 | surt
# Processing Record 35 of Set 9 | treinta y tres
# Processing Record 36 of Set 9 | omsukchan
# Processing Record 37 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 38 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 39 of Set 9 | amparai
# City not found. Skipping...
# Processing Record 40 of Set 9 | truckee
# Processing Record 41 of Set 9 | walvis bay
# Processing Record 42 of Set 9 | mae sai
# Processing Record 43 of Set 9 | yarada
# Processing Record 44 of Set 9 | mvuma
# Processing Record 45 of Set 9 | waipawa
# Processing Record 46 of Set 9 | khaga
# Processing Record 47 of Set 9 | olafsvik
# Processing Record 48 of Set 9 | sorland
# Processing Record 49 of Set 9 | puri
# Processing Record 50 of Set 9 | mendi
# Processing Record 1 of Set 10 | karachi
# Processing Record 2 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 10 | songjianghe
# Processing Record 4 of Set 10 | vardo
# Processing Record 5 of Set 10 | ako
# Processing Record 6 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 10 | saryg-sep
# Processing Record 8 of Set 10 | springdale
# Processing Record 9 of Set 10 | la asuncion
# Processing Record 10 of Set 10 | sohag
# Processing Record 11 of Set 10 | cubuk
# Processing Record 12 of Set 10 | ampanihy
# Processing Record 13 of Set 10 | flin flon
# Processing Record 14 of Set 10 | cristobal obregon
# Processing Record 15 of Set 10 | donnacona
# Processing Record 16 of Set 10 | kilindoni
# Processing Record 17 of Set 10 | meadow lake
# Processing Record 18 of Set 10 | grand gaube
# Processing Record 19 of Set 10 | ipameri
# Processing Record 20 of Set 10 | hami
# Processing Record 21 of Set 10 | dombarovskiy
# Processing Record 22 of Set 10 | carauari
# Processing Record 23 of Set 10 | oriximina
# Processing Record 24 of Set 10 | vanimo
# Processing Record 25 of Set 10 | empangeni
# Processing Record 26 of Set 10 | vao
# Processing Record 27 of Set 10 | hirado
# Processing Record 28 of Set 10 | turayf
# Processing Record 29 of Set 10 | cabedelo
# Processing Record 30 of Set 10 | saint anthony
# Processing Record 31 of Set 10 | itau de minas
# Processing Record 32 of Set 10 | skibbereen
# Processing Record 33 of Set 10 | yining
# Processing Record 34 of Set 10 | raudeberg
# Processing Record 35 of Set 10 | miquelon
# Processing Record 36 of Set 10 | sept-iles
# Processing Record 37 of Set 10 | hay river
# Processing Record 38 of Set 10 | maniitsoq
# Processing Record 39 of Set 10 | barroualie
# City not found. Skipping...
# Processing Record 40 of Set 10 | alofi
# Processing Record 41 of Set 10 | cayeli
# Processing Record 42 of Set 10 | denia
# Processing Record 43 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 44 of Set 10 | pyay
# Processing Record 45 of Set 10 | aripuana
# Processing Record 46 of Set 10 | lephepe
# City not found. Skipping...
# Processing Record 47 of Set 10 | mehamn
# Processing Record 48 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 49 of Set 10 | katsuyama
# Processing Record 50 of Set 10 | lahijan
# Processing Record 1 of Set 11 | kavieng
# Processing Record 2 of Set 11 | kolokani
# Processing Record 3 of Set 11 | bristol
# Processing Record 4 of Set 11 | ha tinh
# Processing Record 5 of Set 11 | sur
# Processing Record 6 of Set 11 | tanout
# Processing Record 7 of Set 11 | caxito
# Processing Record 8 of Set 11 | krasnaya gora
# Processing Record 9 of Set 11 | gravdal
# Processing Record 10 of Set 11 | marawi
# Processing Record 11 of Set 11 | dourbali
# Processing Record 12 of Set 11 | enterprise
# Processing Record 13 of Set 11 | lucea
# Processing Record 14 of Set 11 | darya khan mari
# City not found. Skipping...
# Processing Record 15 of Set 11 | mushie
# Processing Record 16 of Set 11 | cutervo
# Processing Record 17 of Set 11 | tete
# Processing Record 18 of Set 11 | obera
# Processing Record 19 of Set 11 | berlevag
# Processing Record 20 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 21 of Set 11 | listvyanskiy
# Processing Record 22 of Set 11 | sergeyevka
# Processing Record 23 of Set 11 | pyshchug
# Processing Record 24 of Set 11 | loum
# Processing Record 25 of Set 11 | kutum
# Processing Record 26 of Set 11 | soyo
# Processing Record 27 of Set 11 | shimoda
# Processing Record 28 of Set 11 | praxedis guerrero
# Processing Record 29 of Set 11 | sandy bay
# Processing Record 30 of Set 11 | sarkand
# Processing Record 31 of Set 11 | halifax
# Processing Record 32 of Set 11 | inirida
# Processing Record 33 of Set 11 | hambantota
# Processing Record 34 of Set 11 | zhangye
# Processing Record 35 of Set 11 | kantilo
# Processing Record 36 of Set 11 | auki
# Processing Record 37 of Set 11 | poya
# Processing Record 38 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 11 | bonthe
# Processing Record 40 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 11 | acajutla
# Processing Record 42 of Set 11 | virudunagar
# Processing Record 43 of Set 11 | gizo
# Processing Record 44 of Set 11 | richards bay
# Processing Record 45 of Set 11 | beloha
# Processing Record 46 of Set 11 | katherine
# Processing Record 47 of Set 11 | ipubi
# Processing Record 48 of Set 11 | isabela
# Processing Record 49 of Set 11 | camana
# Processing Record 50 of Set 11 | fatsa
# Processing Record 1 of Set 12 | atocha
# Processing Record 2 of Set 12 | laukaa
# Processing Record 3 of Set 12 | victoria point
# Processing Record 4 of Set 12 | zhoukou
# Processing Record 5 of Set 12 | chimoio
# Processing Record 6 of Set 12 | vallenar
# Processing Record 7 of Set 12 | fortuna
# Processing Record 8 of Set 12 | marienburg
# Processing Record 9 of Set 12 | huarmey
# Processing Record 10 of Set 12 | melville
# Processing Record 11 of Set 12 | san jose
# Processing Record 12 of Set 12 | ayagoz
# Processing Record 13 of Set 12 | quatre cocos
# Processing Record 14 of Set 12 | pangoa
# Processing Record 15 of Set 12 | tomatlan
# Processing Record 16 of Set 12 | leningradskiy
# Processing Record 17 of Set 12 | bamenda
# Processing Record 18 of Set 12 | san cristobal
# Processing Record 19 of Set 12 | grindavik
# Processing Record 20 of Set 12 | dongsheng
# Processing Record 21 of Set 12 | lexington park
# Processing Record 22 of Set 12 | sabha
# Processing Record 23 of Set 12 | kholodnyy
# Processing Record 24 of Set 12 | nador
# Processing Record 25 of Set 12 | bulancak
# Processing Record 26 of Set 12 | caravelas
# Processing Record 27 of Set 12 | paamiut
# Processing Record 28 of Set 12 | benguela
# Processing Record 29 of Set 12 | misratah
# Processing Record 30 of Set 12 | niteroi
# Processing Record 31 of Set 12 | toora-khem
# Processing Record 32 of Set 12 | najran
# Processing Record 33 of Set 12 | vanavara
# Processing Record 34 of Set 12 | likasi
# Processing Record 35 of Set 12 | kimbe
# Processing Record 36 of Set 12 | okato
# Processing Record 37 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 38 of Set 12 | dengzhou
# Processing Record 39 of Set 12 | kailua
# Processing Record 40 of Set 12 | puerto princesa
# Processing Record 41 of Set 12 | highland
# Processing Record 42 of Set 12 | seoul
# Processing Record 43 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 12 | duluth
# Processing Record 45 of Set 12 | zaranj
# Processing Record 46 of Set 12 | santa rosa
# Processing Record 47 of Set 12 | lagoa
# Processing Record 48 of Set 12 | deputatskiy
# Processing Record 49 of Set 12 | fortuna foothills
# Processing Record 50 of Set 12 | soke
# Processing Record 1 of Set 13 | nosy varika
# Processing Record 2 of Set 13 | gazli
# Processing Record 3 of Set 13 | linxia
# Processing Record 4 of Set 13 | moose factory
# Processing Record 5 of Set 13 | narsaq
# Processing Record 6 of Set 13 | makubetsu
# Processing Record 7 of Set 13 | hannibal
# Processing Record 8 of Set 13 | inta
# Processing Record 9 of Set 13 | chum phae
# Processing Record 10 of Set 13 | saint-pierre
# Processing Record 11 of Set 13 | sibu
# Processing Record 12 of Set 13 | barvinkove
# Processing Record 13 of Set 13 | rochegda
# Processing Record 14 of Set 13 | port hedland
# Processing Record 15 of Set 13 | san juan
# Processing Record 16 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 13 | ossora
# Processing Record 18 of Set 13 | moree
# Processing Record 19 of Set 13 | beringovskiy
# Processing Record 20 of Set 13 | ridgecrest
# Processing Record 21 of Set 13 | newport
# Processing Record 22 of Set 13 | les cayes
# Processing Record 23 of Set 13 | karpogory
# Processing Record 24 of Set 13 | ingham
# Processing Record 25 of Set 13 | bara
# Processing Record 26 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 13 | bridgeton
# Processing Record 28 of Set 13 | cabra
# Processing Record 29 of Set 13 | saldanha
# Processing Record 30 of Set 13 | tamiahua
# Processing Record 31 of Set 13 | carutapera
# Processing Record 32 of Set 13 | palm coast
# Processing Record 33 of Set 13 | rudsar
# Processing Record 34 of Set 13 | bonfim
# Processing Record 35 of Set 13 | arman
# Processing Record 36 of Set 13 | khuzdar
# Processing Record 37 of Set 13 | jahrom
# City not found. Skipping...
# Processing Record 38 of Set 13 | tolga
# Processing Record 39 of Set 13 | yulara
# Processing Record 40 of Set 13 | chiquinquira
# Processing Record 41 of Set 13 | draganesti-vlasca
# Processing Record 42 of Set 13 | antofagasta
# Processing Record 43 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 13 | kargasok
# Processing Record 45 of Set 13 | kota kinabalu
# Processing Record 46 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 13 | bagdarin
# Processing Record 48 of Set 13 | korla
# Processing Record 49 of Set 13 | thurso
# Processing Record 50 of Set 13 | lloydminster
# Processing Record 1 of Set 14 | noumea
# Processing Record 2 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 3 of Set 14 | fuyu
# Processing Record 4 of Set 14 | san carlos de bariloche
# Processing Record 5 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 6 of Set 14 | koygorodok
# Processing Record 7 of Set 14 | lodja
# Processing Record 8 of Set 14 | vostok
# Processing Record 9 of Set 14 | murray bridge
# Processing Record 10 of Set 14 | nueva guinea
# Processing Record 11 of Set 14 | awjilah
# Processing Record 12 of Set 14 | daloa
# Processing Record 13 of Set 14 | elko
# Processing Record 14 of Set 14 | bam
# Processing Record 15 of Set 14 | kita
# Processing Record 16 of Set 14 | sarangani
# Processing Record 17 of Set 14 | morgan city
# Processing Record 18 of Set 14 | apt
# Processing Record 19 of Set 14 | ihosy
# Processing Record 20 of Set 14 | nisia floresta
# Processing Record 21 of Set 14 | asyut
# Processing Record 22 of Set 14 | biltine
# Processing Record 23 of Set 14 | shenjiamen
# Processing Record 24 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 25 of Set 14 | kommunisticheskiy
# Processing Record 26 of Set 14 | celestun
# Processing Record 27 of Set 14 | ruteng
# Processing Record 28 of Set 14 | ancud
# Processing Record 29 of Set 14 | uglovskoye
# Processing Record 30 of Set 14 | ziro
# Processing Record 31 of Set 14 | magistralnyy
# Processing Record 32 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 33 of Set 14 | north bend
# Processing Record 34 of Set 14 | develi
# Processing Record 35 of Set 14 | pitimbu
# Processing Record 36 of Set 14 | del rio
# Processing Record 37 of Set 14 | warrnambool
# Processing Record 38 of Set 14 | concepcion del oro
# Processing Record 39 of Set 14 | bath
# Processing Record 40 of Set 14 | opuwo
# Processing Record 41 of Set 14 | mandsaur
# Processing Record 42 of Set 14 | nantucket
# Processing Record 43 of Set 14 | luganville
# Processing Record 44 of Set 14 | takhtamygda
# Processing Record 45 of Set 14 | japura
# Processing Record 46 of Set 14 | safford
# Processing Record 47 of Set 14 | brasilia
# Processing Record 48 of Set 14 | ahipara
# Processing Record 49 of Set 14 | khorramshahr
# Processing Record 50 of Set 14 | brighton
# Processing Record 1 of Set 15 | tocopilla
# Processing Record 2 of Set 15 | nagua
# Processing Record 3 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 15 | dwarka
# Processing Record 5 of Set 15 | santa fe
# Processing Record 6 of Set 15 | pangody
# Processing Record 7 of Set 15 | dhidhdhoo
# Processing Record 8 of Set 15 | san policarpo
# Processing Record 9 of Set 15 | husavik
# Processing Record 10 of Set 15 | corinto
# Processing Record 11 of Set 15 | kashi
# Processing Record 12 of Set 15 | stephenville
# Processing Record 13 of Set 15 | salvador
# Processing Record 14 of Set 15 | nizwa
# Processing Record 15 of Set 15 | puerto narino
# Processing Record 16 of Set 15 | saint-joseph
# Processing Record 17 of Set 15 | haines junction
# Processing Record 18 of Set 15 | dryden
# Processing Record 19 of Set 15 | la ronge
# Processing Record 20 of Set 15 | irbil
# Processing Record 21 of Set 15 | natal
# Processing Record 22 of Set 15 | aranos
# Processing Record 23 of Set 15 | ornes
# Processing Record 24 of Set 15 | teahupoo
# Processing Record 25 of Set 15 | leninskoye
# Processing Record 26 of Set 15 | diofior
# Processing Record 27 of Set 15 | wainwright
# Processing Record 28 of Set 15 | vestmanna
# Processing Record 29 of Set 15 | palana
# Processing Record 30 of Set 15 | ibague
# Processing Record 31 of Set 15 | stromness
# Processing Record 32 of Set 15 | tiznit
# Processing Record 33 of Set 15 | farafangana
# Processing Record 34 of Set 15 | tame
# Processing Record 35 of Set 15 | coahuayana
# Processing Record 36 of Set 15 | wanlaweyn
# Processing Record 37 of Set 15 | karpathos
# Processing Record 38 of Set 15 | kurilsk
# Processing Record 39 of Set 15 | ashland
# Processing Record 40 of Set 15 | broken hill
# Processing Record 41 of Set 15 | lindi
# Processing Record 42 of Set 15 | cap malheureux
# Processing Record 43 of Set 15 | mecca
# Processing Record 44 of Set 15 | sokolskoye
# Processing Record 45 of Set 15 | qasigiannguit
# Processing Record 46 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 15 | pyinmana
# Processing Record 48 of Set 15 | manzhouli
# Processing Record 49 of Set 15 | sorong
# Processing Record 50 of Set 15 | doha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have (#691 was example number)
len(city_data)
# Out:
# 692

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Pimenta Bueno -11.6725  -61.1936     72.73        89          96
# 1             Samarai -10.6167  150.6667     84.99        72          50
# 2              Anadyr  64.7500  177.4833     36.10        93          40
# 3              Hobart -42.8794  147.3294     51.66        65          75
# 4  Chalette-Sur-Loing  48.0134    2.7359     52.07        90         100
# 5         Tuktoyaktuk  69.4541 -133.0374     -5.80        84          20
# 6            Ishigaki  24.3448  124.1572     73.53       100          75
# 7          Codrington -38.2667  141.9667     53.83        57          89
# 8         New Norfolk -42.7826  147.0587     51.30        71          98
# 9            Cidreira -30.1811  -50.2056     69.62        60           6
#
#    Wind Speed Country       Current Weather
# 0        1.79      BR  heavy intensity rain
# 1       12.97      PG      scattered clouds
# 2       38.03      RU      scattered clouds
# 3       17.27      AU         broken clouds
# 4       10.20      FR       overcast clouds
# 5        8.05      CA            few clouds
# 6        8.05      JP                  mist
# 7       13.65      AU       overcast clouds
# 8        5.01      AU       overcast clouds
# 9        8.12      BR             clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Weather'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df.rename(columns= {"Max Temp": "Max Temp($^\circ$F)"}, inplace = True)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp($^\circ$F)", 
                    "Humidity", "Cloudiness", "Wind Speed", "Current Weather"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp($^\circ$F)  \
# 0       Pimenta Bueno      BR -11.6725  -61.1936                72.73
# 1             Samarai      PG -10.6167  150.6667                84.99
# 2              Anadyr      RU  64.7500  177.4833                36.10
# 3              Hobart      AU -42.8794  147.3294                51.66
# 4  Chalette-Sur-Loing      FR  48.0134    2.7359                52.07
# 5         Tuktoyaktuk      CA  69.4541 -133.0374                -5.80
# 6            Ishigaki      JP  24.3448  124.1572                73.53
# 7          Codrington      AU -38.2667  141.9667                53.83
# 8         New Norfolk      AU -42.7826  147.0587                51.30
# 9            Cidreira      BR -30.1811  -50.2056                69.62
#
#    Humidity  Cloudiness  Wind Speed       Current Weather
# 0        89          96        1.79  heavy intensity rain
# 1        72          50       12.97      scattered clouds
# 2        93          40       38.03      scattered clouds
# 3        65          75       17.27         broken clouds
# 4        90         100       10.20       overcast clouds
# 5        84          20        8.05            few clouds
# 6       100          75        8.05                  mist
# 7        57          89       13.65       overcast clouds
# 8        71          98        5.01       overcast clouds
# 9        60           6        8.12             clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp($^\circ$F)    float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Weather         object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
